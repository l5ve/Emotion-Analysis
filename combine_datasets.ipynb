# %%
import os
import pandas as pd
cwd = os.path.abspath('') 
files = os.listdir(cwd)

# %%
df = pd.DataFrame()

# %%
for year in range(2006, 2020):
    #data = pd.read_csv("./Analysis_Result_2/result_"+str(year)+" (1).csv")
    df=df.append(pd.read_csv("./Analysis_Result_2/result_"+str(year)+" (1).csv"),ignore_index=True)

# %%
df.to_csv("./User Emotion/data/song_lyrics.csv")

# %%
df=pd.read_csv("./User Emotion/data/song_lyrics.csv")
df
# Out:
#       Unnamed: 0             title                             artist  year  \
# 0              0       Temperature                          Sean Paul  2006
# 1              1       Promiscuous  Nelly Furtado Featuring Timbaland  2006
# 2              2  You're Beautiful                        James Blunt  2006
# 3              3    Hips Don't Lie      Shakira Featuring Wyclef Jean  2006
# 4              4         Unwritten                Natasha Bedingfield  2006
# ...          ...               ...                                ...   ...
# 1308        1308       Eyes On You                         Chase Rice  2019
# 1309        1309     All To Myself                         Dan + Shay  2019
# 1310        1310         Boyfriend       Ariana Grande & Social House  2019
# 1311        1311      Walk Me Home                               P!nk  2019
# 1312        1312           Robbery                         Juice WRLD  2019
#
# ...
